# %%
IMAGE_PATH = '/users/ranerchow/OCRPrac/images/cyn.png'
original_img = cv2.imread(IMAGE_PATH)
# Out:
# [ WARN:0@153.306] global loadsave.cpp:275 findDecoder imread_('/users/ranerchow/OCRPrac/images/cyn.png'): can't open/read file: check file path/integrity

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def detect_card_robust(img):
    """
    Multiple detection approaches for different card types
    """
    # Border detection
    def method_border_detection(img):
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        blurred = cv2.GaussianBlur(gray, (15, 15), 0)
        thresh = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_MEAN_C, 
                                       cv2.THRESH_BINARY, 21, 10)
        kernel = np.ones((5,5), np.uint8)
        thresh = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)
        thresh = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel)
        contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        return contours, thresh
    
    def method_edge_detection(img):
        pass
    
    def method_color_detection(img):
        pass
    
    # Placeholder return
    return img, (0, 0, img.shape[1], img.shape[0]), {}

# Minimal test
def test_robust_detection():
    original_img = cv2.imread(IMAGE_PATH)
    detected_card, bbox, debug_imgs = detect_card_robust(original_img)
    print("Border detection test passed")
    return True

test_robust_detection()
# Out:
# [ WARN:0@33.510] global loadsave.cpp:275 findDecoder imread_('cyn.png'): can't open/read file: check file path/integrity
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 37
#      34     print("Border detection test passed")
#      35     return True
# ---> 37 test_robust_detection()
#
# Cell In[9], line 33, in test_robust_detection()
#      31 def test_robust_detection():
#      32     original_img = cv2.imread(IMAGE_PATH)
# ---> 33     detected_card, bbox, debug_imgs = detect_card_robust(original_img)
#      34     print("Border detection test passed")
#      35     return True
#
# Cell In[9], line 28, in detect_card_robust(img)
#      25     pass
#      27 # Placeholder return
# ---> 28 return img, (0, 0, img.shape[1], img.shape[0]), {}
#
# AttributeError: 'NoneType' object has no attribute 'shape'
