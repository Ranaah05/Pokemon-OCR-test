# %%
IMAGE_PATH = '../images/ray.png'

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def detect_card_basic(img):
    """
    Basic card detection using simple thresholding
    """
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Simple threshold
    _, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    # Find contours
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    
    if not contours:
        return None, None
    
    # Find largest contour
    largest_contour = max(contours, key=cv2.contourArea)
    x, y, w, h = cv2.boundingRect(largest_contour)
    
    # Simple crop
    cropped_card = img[y:y+h, x:x+w]
    return cropped_card, (x, y, w, h)

def test_basic_detection(image_path):
    """
    Test the basic detection
    """
    img = cv2.imread(image_path)
    
    result, bbox = detect_card_basic(img)
    
    if result is not None:
        # Show result
        plt.figure(figsize=(10, 5))
        
        plt.subplot(1, 2, 1)
        plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
        plt.title('Original')
        
        plt.subplot(1, 2, 2)
        plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
        plt.title('Detected Card')
        
        plt.tight_layout()
        plt.show()
        
        print(f"Detection successful: {bbox}")
        return True
    else:
        print("Detection failed")
        return False
